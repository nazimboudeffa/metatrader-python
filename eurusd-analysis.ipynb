# %%
# EURUSD Analysis

# %%
# Libraries 
import MetaTrader5 as mt5
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime

# %%
# Connect to MetaTrader5 as mt5
mt5.initialize()
# Out:
# True

# %%
# requesting ohlc data
symbol = "EURUSD"
timeframe = mt5.TIMEFRAME_M1

ohlc = mt5.copy_rates_range(symbol, timeframe, datetime(2023, 7, 2), datetime(2023, 7, 8))
ohlc
# Out:
# array([(1688342700, 1.0909 , 1.09099, 1.09085, 1.09097, 13, 41, 0),
#        (1688342760, 1.09097, 1.09097, 1.09083, 1.09097,  3, 43, 0),
#        (1688342820, 1.09097, 1.09098, 1.09097, 1.09098,  2, 42, 0), ...,
#        (1688767080, 1.09671, 1.09671, 1.09657, 1.09663, 42,  6, 0),
#        (1688767140, 1.09663, 1.09678, 1.09663, 1.09669, 51,  6, 0),
#        (1688767200, 1.0967 , 1.0967 , 1.09666, 1.09667, 18,  6, 0)],
#       dtype=[('time', '<i8'), ('open', '<f8'), ('high', '<f8'), ('low', '<f8'), ('close', '<f8'), ('tick_volume', '<u8'), ('spread', '<i4'), ('real_volume', '<u8')])

# %%
# converting ohlc to pandas DataFrame
df = pd.DataFrame(ohlc)
df['time'] = pd.to_datetime(df['time'], unit='s')
df
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2023-07-03 00:05:00  1.09090  1.09099  1.09085  1.09097           13
# 1    2023-07-03 00:06:00  1.09097  1.09097  1.09083  1.09097            3
# 2    2023-07-03 00:07:00  1.09097  1.09098  1.09097  1.09098            2
# 3    2023-07-03 00:08:00  1.09098  1.09099  1.09098  1.09099            2
# 4    2023-07-03 00:09:00  1.09108  1.09108  1.09108  1.09108            1
# ...                  ...      ...      ...      ...      ...          ...
# 7041 2023-07-07 21:56:00  1.09687  1.09687  1.09671  1.09671           63
# 7042 2023-07-07 21:57:00  1.09671  1.09672  1.09663  1.09671           30
# 7043 2023-07-07 21:58:00  1.09671  1.09671  1.09657  1.09663           42
# 7044 2023-07-07 21:59:00  1.09663  1.09678  1.09663  1.09669           51
# 7045 2023-07-07 22:00:00  1.09670  1.09670  1.09666  1.09667           18
#
#       spread  real_volume
# 0         41            0
# ...

# %%
fig = px.line(df, x='time', y='close', title='EURUSD - Close Prices')
display(fig)
# Out:
# <div>                            <div id="32af5243-00dd-44af-b8cf-724df7ad5fb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32af5243-00dd-44af-b8cf-724df7ad5fb8")) {                    Plotly.newPlot(                        "32af5243-00dd-44af-b8cf-724df7ad5fb8",                        [{"hovertemplate":"time=%{x}\u003cbr\u003eclose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2023-07-03T00:05:00","2023-07-03T00:06:00","2023-07-03T00:07:00","2023-07-03T00:08:00","2023-07-03T00:09:00","2023-07-03T00:10:00","2023-07-03T00:11:00","2023-07-03T00:12:00","2023-07-03T00:13:00","2023-07-03T00:14:00","2023-07-03T00:15
# ...

# %%
dfpl = df[6000:7046]
dfpl
# Out:
#                     time     open     high      low    close  tick_volume  \
# 6000 2023-07-07 04:35:00  1.08880  1.08880  1.08875  1.08876           52
# 6001 2023-07-07 04:36:00  1.08876  1.08876  1.08868  1.08871           34
# 6002 2023-07-07 04:37:00  1.08870  1.08870  1.08861  1.08865           50
# 6003 2023-07-07 04:38:00  1.08866  1.08875  1.08863  1.08874           31
# 6004 2023-07-07 04:39:00  1.08873  1.08877  1.08870  1.08875           53
# ...                  ...      ...      ...      ...      ...          ...
# 7041 2023-07-07 21:56:00  1.09687  1.09687  1.09671  1.09671           63
# 7042 2023-07-07 21:57:00  1.09671  1.09672  1.09663  1.09671           30
# 7043 2023-07-07 21:58:00  1.09671  1.09671  1.09657  1.09663           42
# 7044 2023-07-07 21:59:00  1.09663  1.09678  1.09663  1.09669           51
# 7045 2023-07-07 22:00:00  1.09670  1.09670  1.09666  1.09667           18
#
#       spread  real_volume
# 6000       6            0
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=dfpl.index,
                open=dfpl['open'],
                high=dfpl['high'],
                low=dfpl['low'],
                close=dfpl['close'])])

fig.show()
# Out:
# <div>                            <div id="9a7d5bc5-6c07-4f08-b9dd-e49bf8ebbf31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a7d5bc5-6c07-4f08-b9dd-e49bf8ebbf31")) {                    Plotly.newPlot(                        "9a7d5bc5-6c07-4f08-b9dd-e49bf8ebbf31",                        [{"close":[1.08876,1.08871,1.08865,1.08874,1.08875,1.08878,1.08882,1.08871,1.08875,1.08875,1.08876,1.08874,1.08878,1.08876,1.08879,1.08875,1.08878,1.08877,1.08883,1.08879,1.08874,1.08879,1.08864,1.08864,1.08868,1.08869,1.08877,1.08879,1.08874,1.08867,1.08875,1.08875,1.08863,1.08863,1.08871,1.08878,1.08882,1.08868,1.08869,1.08863,1.08864,1.08862,1.08854,1.08859,1.08857,1.08853,1.08856,1.08854,1.08852,1.08854,1.08851,1.08847,1.08841,1.08847,1.08842,1.08843,1.08843,1
# ...
