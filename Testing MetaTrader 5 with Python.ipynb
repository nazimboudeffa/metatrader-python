# %%
import MetaTrader5 as mt5

# %%
mt5.initialize()
# Out:
# True

# %%
symbols = mt5.symbols_get()
for symbol in symbols:
    print(symbol.name)
# Out:
# EURUSD
# GBPUSD
# USDCAD
# USDCHF
# USDJPY
# AUDCAD
# AUDCHF
# AUDJPY
# AUDNZD
# AUDUSD
# CADCHF
# CADJPY
# CHFJPY
# EURAUD
# EURCAD
# EURCHF
# EURGBP
# EURJPY
# EURNZD
# GBPAUD
# GBPCAD
# GBPCHF
# GBPJPY
# EURCZK
# EURHUF
# EURPLN
# EURRUB
# USDBRL
# USDCLP
# USDCNH
# USDCZK
# USDMXN
# USDPLN
# USDRON
# USDRUB
# GBPNZD
# NZDCAD
# NZDCHF
# NZDJPY
# NZDUSD
# COPPER
# GOLD
# PALLADIUM
# PLATINUM
# SILVER
# [AEX25]
# [ASX200]
# [CAC40]
# [Canada60]
# [DAX40]
# [DJI30]
# [FTSE100]
# [HSCEI50]
# [HSI50]
# [IBEX35]
# [JP225]
# [MDAX50]
# [NQ100]
# [OBX25]
# [SMI20]
# [SP500]
# [STOXX50]
# [SouthAfrica40]
# [TECDAX30]
# BRENT
# CRUDOIL
# NGAS
# WTI
# ADAUSD
# ALGUSD
# ATMUSD
# BCHBTC
# BCHEUR
# BCHUSD
# BTCEUR
# BTCUSD
# DGEUSD
# DOTUSD
# DSHBTC
# DSHEUR
# DSHUSD
# EOSBTC
# EOSEUR
# EOSUSD
# ETCBTC
# ETCEUR
# ETCUSD
# ETHBTC
# ETHEUR
# ETHUSD
# KSMUSD
# LNKUSD
# LTCBTC
# LTCEUR
# LTCUSD
# MTCUSD
# SOLUSD
# UNIUSD
# XLMBTC
# XLMEUR
# XLMUSD
# XMRBTC
# XMREUR
# XMRUSD
# XRPBTC
# XRPEUR
# XRPUSD
# ZECBTC
# ZECEUR
# ZECUSD
# #AEEM
# #BNK
# #BNKE
# #C50
# #CAC
# #CEUG
# #CMU
# #ERO
# #STZP
# #TPXH
# #USA
# #DBXD
# #EXS1
# #IDVY
# #IJPA
# #IMEU
# #VERX
# #VEUR
# #LYXIB
# #CSSMI
# #SMICHA
# #EMIM
# #EUE
# #IEMB
# #ISF
# #IUKP
# #IUSA
# #IWDP
# #L100
# #MIDDL
# #SEML
# #SJPA
# #SLXX
# #VMID
# #VUKE
# #VUSA
# #XESX
# #AGG
# #AMLP
# #ANGL
# #ARKW
# #AOR
# #ASHR
# #BIV
# #BKLN
# #BLV
# #BNDUS
# #BSV
# #BWX
# #CWB
# #CWI
# #DBA
# #DBC
# #DBEF
# #DBEU
# #DBJP
# #DBO
# #DFE
# #DGRO
# #DIAUS
# #DON
# #DSI
# #DUSTUS
# #DWX
# #DXJ
# #EEMUS
# #EFA
# #EIDO
# #EMLC
# #EMLP
# #EPI
# #EPP
# #EWA
# #EWC
# #EWD
# #EWG
# #EWH
# #EWI
# #EWJ
# #EWL
# #EWM
# #EWP
# #EWQ
# #EWS
# #EWT
# #EWU
# #EWW
# #EWY
# #EWZ
# #EZA
# #EZU
# #FBT
# #FDLUS
# #FDN
# #FEZ
# #FLOT
# #FLRN
# #FNCL
# #FNDE
# #FNDX
# #FTEC
# #FXD
# #FXH
# #FXI
# #FXO
# #FXR
# #GDX
# #GDXJ
# #GLDAR
# #GBIL
# #GMF
# #GNR
# #GSG
# #GUNR
# #GWX
# #GXC
# #HACK
# #HDV
# #HEDJ
# #HEZU
# #HYD
# #HYG
# #HYS
# #IAT
# #IAU
# #ICF
# #IDU
# #IEMG
# #IEUR
# #IEV
# #IGEUS
# #IGLB
# #IGM
# #IGV
# #IHF
# #IHI
# #IJH
# #IJR
# #ILF
# #ITA
# #ITB
# #ITOT
# #IVE
# #IVV
# #IVW
# #IWB
# #IWD
# #IWF
# #IWM
# #IWN
# #IWO
# #IWP
# #IWR
# #IWS
# #IXC
# #IXJ
# #IXN
# #IYC
# #IYE
# #IYF
# #IYG
# #IYH
# #IYJ
# #IYK
# #IYM
# #IYR
# #IYT
# #IYW
# #JNK
# #KBE
# #KRE
# #KWEB
# #KXI
# #LIT
# #LQD
# #MDY
# #MGC
# #MJ
# #MLPA
# #MOO
# #MINTUS
# #MUB
# #NUGT
# #OEF
# #OIH
# #PBW
# #PCY
# #PGF
# #PGX
# #PHYS
# #PPLT
# #REM
# #RSP
# #RWO
# #RWR
# #RWX
# #RYT
# #SCHBUS
# #SCHDUS
# #SCHE
# #SCHF
# #SCHG
# #SCHH
# #SCHM
# #SCHV
# #SCHX
# #SCHZ
# #SDIV
# #SDYUS
# #SGOL
# #SH
# #SHM
# #SIVR
# #SLV
# #SMH
# #SPHD
# #SPIB
# #SPLG
# #SPTL
# #SPTM
# #SPY
# #SPLVUS
# #SPYG
# #SPYV
# #SRLN
# #SUSA
# #TBT
# #THD
# #TAN
# #TIP
# #UNG
# #USO
# #UUP
# #VAW
# #VB
# #VCR
# #VDC
# #VDE
# #VEA
# #VEU
# #VFH
# #VGK
# #VGT
# #VHT
# #VIOO
# #VNQ
# #VO
# #VOO
# #VOOG
# #VOX
# #VPL
# #VPU
# #VRP
# #VT
# #VTEB
# #VTI
# #VTV
# #VUG
# #VV
# #VWO
# #VXF
# #VYM
# #XBI
# #XHB
# #XLB
# #XLC
# #XLE
# #XLF
# #XLI
# #XLK
# #XLP
# #XLRE
# #XLU
# #XLV
# #XLY
# #XME
# #XOP
# #XPH
# #XRT
# #ACWV
# #ECH
# #EEMV
# #EFAV
# #EFG
# #EFV
# #EMHY
# #GOVT
# #ESGV
# #HEFA
# #IDV
# #IEFA
# #IGHG
# #INDA
# #IYZ
# #MTUM
# #NEAR
# #NOBL
# #PICK
# #QUAL
# #USMV
# #VLUE
# #AAXJ
# #ACWX
# #BBH
# #BNDX
# #BOTZ
# #CIBR
# #DGRW
# #DVY
# #EMB
# #ESGD.US
# #EUFN
# #FEP
# #FNX
# #ESGE.US
# #ESGU.US
# #FTCS
# #HEWG
# #HYLS
# #IBB
# #ICLN
# #IEF
# #IEI
# #IFGL
# #IGF
# #INDY
# #IUSG
# #IUSV
# #IXUS
# #KBWB
# #KBWY
# #LMBS
# #MBBUS
# #MCHI
# #PDBC
# #PFF
# #PHOUS
# #PID
# #QQQ
# #QCLN
# #QTEC
# #ROBO
# #SCZ
# #SHV
# #SHY
# #SKYY
# #SOXX
# #TDIV
# #TLTUS
# #TUR
# #VCIT
# #VCLT
# #VCSH
# #VNQI
# #VGIT
# #VTIP
# #VXUS
# EURNOK
# EURRON
# EURSEK
# GBPGBX
# GBPPLN
# GBPSGD
# GBXUSD
# GLDUSD
# USDAED
# USDARS
# USDBGN
# USDCOP
# USDCRC
# USDECS
# USDGHS
# USDHKD
# USDHRK
# USDHUF
# USDIDR
# USDJOD
# USDKES
# USDLAK
# USDMMK
# USDNGN
# USDNOK
# USDPEN
# USDSEK
# USDSGD
# USDTZS
# USDUAH
# XAUEUR
# USDUGX
# USDUSX
# USDVND
# [EURX]
# [USDX]
# ARABICA
# COCOA
# COTTON
# ORANGE.JUICE
# ROBUSTA
# SUGAR.RAW
# SUGAR.WHITE
# #A
# #AA
# #AAT
# #ABBV
# #ABEV
# #ABM
# #ABT
# #ABX
# #ABR
# #ACCO
# #ACM
# #ACN
# #AAPL
# #ADBE
# #ADC
# #ADNT
# #ADSK
# #AEE
# #AEG
# #AEL
# #ADM.US
# #ADT
# #AEM
# #AEO
# #AEP
# #AER
# #AES
# #AG
# #AGCO
# #AGI
# #AGM
# #AGNC
# #AGO
# #AGRO
# #AGX
# #AHH
# #AIG
# #AIN
# #AIT
# #AJG
# #AJRD
# #AKR
# #AL
# #ALE
# #ALEX
# #ALG
# #ALB.US
# #ALGN
# #ALL
# #ALLE
# #ALC
# #ALLY
# #ALSN.US
# #ALX
# #AM.US
# #AMC
# #AMD
# #AMCR
# #AME
# #AMGN
# #AMH
# #AMN
# #AMP
# #AMX
# #AN
# #ANET
# #ANF
# #ANSS
# #AON
# #AOS
# #APA
# #APAM1
# #APD
# #APH
# #APLE
# #APO
# #APRN
# #APTV
# #AR
# #AQN
# #ARCC
# #ARCH
# #ARCO
# #ARE
# #AAOI
# #AAON
# #AAP
# #ABC
# #ABCB
# #ABMD
# #AAL.US
# #ABNB.US
# #ACAD
# #ACHC
# #ACIW
# #ACLS
# #ACOR
# #ACRS
# #ADI
# #ADTN
# #AEIS
# #ACGL
# #AFG
# #AFL
# #AGII
# #AGIO
# #AIV
# #AIZ
# #AKAM
# #AKBA
# #ALGT
# #ALK
# #ALKS
# #ALNY
# #ALRM
# #ADP.US
# #AMAT
# #AMBA
# #AMBC
# #AMCX
# #AMED
# #AMKR
# #AMPH
# #AMRN
# #AMSF
# #AMT
# #AMWD
# #AMZN
# #ANAT
# #ANDE
# #ANGI
# #ANGO
# #ANIK
# #ANIP
# #APOG
# #APPF
# #APPN
# #ARCB
# #ARLP
# #ARMK
# #ASTE
# #ATNI
# #ATRC
# #ATRO
# #ATSG
# #ATVI
# #AVAV
# #ATO
# #AVB
# #AVY
# #AXDX
# #AXS
# #AY
# #ASML.US
# #AXON.US
# #AZPN
# #ADPT.US
# #ADUS.US
# #AGYS.US
# #ALLO.US
# #AMEH.US
# #APPS.US
# #ARQT.US
# #AVID.US
# #BANR
# #BAP
# #BCOR
# #BCPC
# #BECN
# #ASAN
# #ASH
# #ASR
# #ASX
# #ATHM
# #ATR
# #ATUS
# #AU
# #AVAL
# #AXTA
# #AYX
# #BA
# #BABA
# #BAH
# #BAK
# #BAM
# #BC
# #BCE
# #BCH
# #BCS
# #BE
# #BERY
# #BFA
# #BFAM
# #BG
# #BHC
# #BHP
# #BIP
# #BJRI
# #BK
# #BKCC
# #AZN
# #BKNG
# #BGNE
# #BIGC
# #BILI
# #BL
# #BLBD
# #BLDP
# #BJ
# #BKI
# #BLD
# #BLDR
# #BLMN
# #BLUE
# #BNTX
# #BPMC
# #BPOP
# #BR
# #BRFS
# #BRKL
# #BRKR
# #BSMX
# #BUSE
# #CAG
# #CAH
# #BBIO.US
# #BRP.US
# #CAKE
# #CALM
# #CAMP
# #CAR
# #CASH
# #BYND
# #BZUN
# #CASY
# #CATY
# #CBOE
# #CBRL
# #CCOI
# #CDEV
# #CDNS
# #CDW
# #CENT
# #CENX
# #CEVA
# #CFFN
# #CG
# #CGNX
# #CHCO
# #CHDN
# #CHRS
# #CIGI
# #CLVS
# #CLX
# #CMCO
# #CMCSA
# #CME
# #CMI
# #CMPR
# #CMRX
# #CNMD
# #CNOB
# #CNQ
# #CNSL
# #CNX
# #COF
# #COHU
# #COLB
# #COIN.US
# #COLM
# #CONN
# #COO
# #CORT
# #COST
# #CRON
# #CROX
# #CRUS
# #CRWD
# #CSL
# #CVET
# #CYBR
# #CZR
# #DB
# #DBX
# #DCI
# #DSGX
# #EEFT
# #ELS
# #ENTG
# #ERIC
# #EVBG
# #EWBC
# #EXAS
# #EXPI.US
# #FAF
# #FFIN
# #FIVE
# #FIVN
# #FLEX
# #FMX
# #FNF
# #FNV
# #FOXF
# #FTS
# #GDS
# #GGG
# #GH
# #GLPI
# #GTLS
# #HALO
# #HELE
# #HQY
# #HTHT
# #HZNP
# #IART
# #IBKR
# #ICLR
# #IEP
# #INVH
# #IQ
# #IRDM
# #IRTC
# #JBLU
# #JD
# #CPLP
# #CSCO
# #CSGS
# #CSII
# #CSIQ
# #CSTE
# #CSX
# #CTAS
# #CTBI
# #CTRE
# #CTSH
# #CVBF
# #CVGW
# #CVLT
# #CWST
# #CYTK
# #DDOG.US
# #DE
# #CARG.US
# #CHEF.US
# #CLDX.US
# #CLNE.US
# #CPRX.US
# #CRSR.US
# #CRTO.US
# #CSWI.US
# #CVCO.US
# #DBVT
# #DENN
# #DHC
# #DIOD
# #DISH
# #DORM
# #DOCU
# #DOV
# #DVAX
# #DXPE
# #EBAY
# #DCPH.US
# #DCT.US
# #EBIX
# #ECPG
# #EDIT
# #EFSC
# #EGBN
# #EGRX
# #ENIC
# #ENSG
# #ENTA
# #ERII
# #ESPR
# #ENPH.US
# #ETSY
# #EXLS
# #EXPD
# #EXPO
# #EXTR
# #EYE
# #EZPW
# #EVOP.US
# #FARM
# #FARO
# #FAST
# #FB
# #FBNC
# #FDX
# #FELE
# #FFBC
# #FFIC
# #FGEN
# #FHB
# #FIBK
# #FLWS
# #FMC
# #FOLD
# #FORM
# #FORR
# #FOSL
# #FOX
# #FOXA
# #FRGI
# #FRME
# #FULT
# #FWRD
# #FATE.US
# #FLYW.US
# #GBCI
# #GBDC
# #GGAL
# #GGB
# #GIII
# #GILD
# #GIS
# #GLNG
# #GLRE
# #GOGO
# #GOOD
# #GOOG
# #GPRE
# #GPRO
# #GRPN
# #GSM
# #GDEN.US
# #GOGL.US
# #HA
# #HAFC
# #HAIN
# #HAYN
# #HBNC
# #HCM
# #HCSG
# #HEES
# #HFWA
# #HIBB
# #HIW
# #HMST
# #HOLI
# #HOMB
# #HONE
# #HOPE
# #HAS.US
# #HRL
# #HRTX
# #HSTM
# #HTBK
# #HTLD
# #HTLF
# #HUBG
# #HURN
# #IBOC
# #HIMX.US
# #HLIT.US
# #IBTX
# #ICFI
# #ICPT
# #ICUI
# #IDCC
# #IFF
# #IIIN
# #IMGN
# #IMKTA
# #INCY
# #INFN
# #INGN
# #INO
# #INSM
# #GOOG.US
# #INTC
# #INVA
# #IOSP
# #IPAR
# #IRBT
# #IRM
# #IRWD
# #INTU.US
# #ISRG
# #ITCI
# #ITRI
# #ITRN
# #IOVA.US
# #ITW
# #IVZ
# #JACK
# #JBSS
# #JJSF
# #JLL
# #JRVR
# #JWN
# #K
# #KALU
# #KE
# #KELYA
# #KFRC
# #KLIC
# #KNSL
# #KRC
# #KRNT
# #KRNY
# #KTOS
# #LANC
# #KRYS.US
# #LAND.US
# #LAUR
# #LBAI
# #LBTYA
# #LBTYK
# #KDP.US
# #LDOS
# #LE
# #LFUS
# #LGIH
# #LGND
# #LILA
# #LI.US
# #LITE
# #LIVN
# #LKFN
# #LMAT
# #LNC
# #LNT
# #LNTH
# #LOB
# #LOCO
# #LOGI
# #LOPE
# #LOW
# #LPLA
# #LPSN
# #LSCC
# #LSTR
# #LTRPA
# #LVS
# #LW
# #LX
# #LXRX
# #LYG
# #MACK
# #LYFT
# #MANH
# #MAR
# #MASI
# #MATW
# #MBUU
# #MBWM
# #MCO
# #MDLZ
# #MDRX
# #MELI
# #MEOH
# #MFG
# #MGA
# #MGEE
# #MGNX
# #MGPI
# #MGRC
# #MHK
# #MHLD
# #MKSI
# #MLM
# #MMLP
# #MMSI
# #MMYT
# #MNRO
# #MOMO
# #MPAA
# #MLCO
# #MPWR
# #MRCY
# #MRTN
# #MSBI
# #MSCI
# #MSEX
# #MRNA
# #MSFT
# #MSI
# #MSTR
# #MTRX
# #MTSI
# #MU
# #MYGN
# #MYRG
# #NATI
# #MARA.US
# #MCRI.US
# #MDGL.US
# #MLKN.US
# #MODV.US
# #NAVI
# #NBIX
# #NBTB
# #NCLH
# #NCMI
# #NEE
# #NEOG
# #NEPT
# #NFBK
# #NFG
# #NFLX
# #NKTR
# #NMIH
# #NMRK
# #NNBR
# #NOV
# #NSIT
# #NTCT
# #NTES
# #NTGR
# #NEO
# #NICE
# #NKLA.US
# #NTNX
# #NUVA
# #NVAX
# #NVCR
# #NVDA
# #NVMI
# #NVO
# #NVS
# #NWBI
# #NXST
# #NYMT
# #OC
# #NXGN.US
# #OCFC
# #OCSL
# #ODP
# #OFIX
# #NWSA
# #OKE
# #OKTA
# #OLLI
# #OMCL
# #OMAB
# #OMER
# #ONB
# #OPK
# #OPTN
# #ORAN
# #ORLY
# #OSIS
# #OSUR
# #OTTR
# #PAAS
# #PACB
# #OPEN.US
# #OTLY.US
# #PAHC
# #PATK
# #PAYX
# #PBYI
# #PCH
# #PCRX
# #PCTY
# #PDCE
# #PDCO
# #PDFS
# #PEBO
# #PEGA
# #PENN
# #PDD
# #PEP
# #PFBC
# #PGC
# #PI
# #PFG.US
# #PII
# #PINC
# #PLAB
# #PLAY
# #PLCE
# #PLUG
# #PLUS
# #PLXS
# #PLYA
# #PNFP
# #PNNT
# #PODD
# #POOL
# #POWI
# #PPBI
# #PPC
# #PRAA
# #PRDO
# #PRFT
# #PRGS
# #PRIM
# #PRTA
# #PRTK
# #PSEC
# #PSMT
# #PTC
# #PTCT
# #PTEN
# #PXD
# #PYPL
# #PZZA
# #QCOM
# #PTON.US
# #QDEL
# #PFC.US
# #PLL.US
# #PLMR.US
# #POSH.US
# #QFIN
# #QLYS
# #QRTEA
# #RARE
# #RBBN
# #RCL
# #RDUS
# #RDWR
# #RETA
# #RGEN
# #RGNX
# #RMBS
# #RNST
# #ROCK
# #ROIC
# #ROK
# #ROLL
# #RPM
# #RRGB
# #RRR
# #IWDAU
# #ABI
# #ACKB
# #AEDEU
# #AGFB
# #AGS
# #ARGX
# #BAR
# #BCART
# #BEFB
# #BEKB
# #BPOST
# #CFEB
# #COFB
# #COLR
# #CYAD
# #DIE
# #ECONB
# #ELI1
# #EURN
# #EVS
# #FAGR
# #GBLB
# #GIMB
# #GREEN
# #IBAB
# #KBC
# #KBCA
# #KIN
# #MELE
# #OBEL
# #ONTEX
# #PROX
# #REC1
# #RET
# #SIP
# #SOF
# #SOLB
# #TESB
# #UCB
# #UMI
# #WDP
# #ALK.B
# #ALMB
# #AMBUB
# #BAVA
# #BO
# #CARL.B
# #CHR
# #COLO.B
# #DANSKE
# #DENERG
# #DFDS
# #DNORD
# #DSV
# #GN
# #ISS
# #JYSK
# #MAERSK.A
# #NKT
# #NOVO.B
# #NZYM.B
# #PAAL.B
# #PNDOR
# #RBREW
# #RILBA
# #ROCK.B
# #SCHO
# #SIM
# #SPNO
# #STG
# #SYDB
# #TOP
# #TRYG
# #VWS
# #ZEAL
# #CGCBV
# #CTY1
# #ELISA
# #FSC
# #HUH
# #KCR
# #KEMIRA
# #KESKOB
# #KNEBV
# #METSB
# #NDA
# #NESTE
# #ORNBV
# #RAIVV
# #SAMPO
# #UNR
# #VALMT
# #WRT1V
# #AB
# #AC
# #AF
# #AI
# #AKE
# #ALD1
# #ACA
# #ALO
# #ALTA
# #AMUN
# #ATE
# #BN
# #BNP
# #BIM
# #BVI
# #CAP
# #BB.FR
# #BON
# #CARM
# #CDI
# #CGG
# #COFA
# #COX
# #DBG1
# #DBV
# #DEC
# #CS.FR
# #DG
# #DIM
# #DSY
# #EDEN
# #EI
# #ELIOR
# #ELIS
# #EN
# #ENGI
# #ENX
# #ERA
# #ETL
# #EUCAR
# #FGR
# #FNAC
# #FP
# #GET
# #GFC
# #GLE
# #GNFT
# #GTT1
# #HO
# #ICAD
# #IPH
# #IPN
# #IPS
# #KER
# #KOF
# #LI
# #LOCAL
# #LR
# #MAU
# #MDM
# #MERY
# #MF
# #ML
# #MMB
# #MMT
# #MRN
# #NK
# #NXI
# #ORA
# #NEOEN
# #ORP
# #POM
# #PUB
# #RAL
# #MC.FR
# #OR
# #RI
# #RBT
# #RIN
# #RMS
# #RCF
# #RF.FR
# #RNO
# #ROTH
# #RUI
# #RXL
# #SAF
# #SAN
# #SK
# #SOP
# #SPIE
# #SW
# #TFI
# #SGO
# #VIE
# #TRI
# #VIRP
# #VK
# #WLN
# #1COV
# #ADJ
# #ADS
# #ADV
# #AIR
# #AIXA
# #ALV
# #AOX
# #ARL
# #B4B
# #BAS
# #BAYN
# #BC8
# #BDT
# #BEI
# #BFSA
# #BMW
# #BNR
# #BOSS
# #BVB
# #BYW6
# #CBK
# #COK
# #CON
# #DAI
# #DBAN
# #DBK
# #DEQ
# #DEZ
# #DHER
# #DIC
# #DRW3
# #DTE
# #DUE
# #EOAN
# #EVD
# #EVK
# #EVT
# #FIE
# #FME
# #FNTN
# #FPE
# #FRA
# #FRE
# #G1A
# #G24
# #GBF
# #GFT
# #GLJ
# #GXI
# #GYC
# #HAB
# #HBH
# #HDD
# #HEI
# #HEN
# #HHFA
# #HLAG
# #HNR1
# #HOT
# #IFX
# #INH
# #JEN
# #JUN3
# #KCO
# #KGX
# #KRN
# #KU2
# #KWS
# #LEO
# #LHA
# #LIN
# #LXS
# #MDG1
# #MEO
# #MOR
# #MRK1
# #MTX1
# #MUV2
# #NDA1
# #NDX1
# #NOEJ
# #O1BC
# #O2D
# #PAH3
# #PBB
# #PFV
# #PSM
# #PUM
# #QIA
# #QSC
# #RAA
# #RHM
# #RWE
# #S92
# #SAP
# #SAX
# #SDF
# #SGL
# #SHA
# #SIE
# #SIX2
# #SKB
# #SOW
# #SRT3
# #STM2
# #SY1
# #SZG
# #SZU
# #TEG
# #TKA
# #TLX
# #TTK
# #TMV.DE
# #UN01
# #UTDI
# #VNA
# #VOS
# #VOW
# #VOW3
# #WAC
# #WCH
# #WSU
# #WUW
# #ZAL
# #ZIL2
# #AALB
# #ABN
# #ACCEL
# #AD
# #ADYEN
# #AKZA
# #ARCAD
# #ASM
# #ASML
# #ASRNL
# #BAMNB
# #BESI
# #BRNL
# #CRBN
# #ECMPA
# #FUR
# #GLPG
# #HEIA
# #HEIO
# #IMCD
# #INGA
# #KENDR
# #KPN
# #LIGHT
# #N4R
# #NN
# #OCI
# #PHIA
# #RAND
# #SBMO
# #SLIGR
# #TKWY
# #TOM2
# #TWEKA
# #UNA
# #VASTN
# #VPK
# #WHA
# #WKL
# #AKER
# #ATEA
# #AUSS
# #BAKKA
# #BRG
# #BWLPG
# #BWO
# #DNO
# #GJF
# #GSF
# #KOG
# #LSG
# #MHG
# #NAS
# #NEL
# #NHY
# #NOD
# #ORK
# #PGS
# #REC
# #SALM
# #SCHA
# #SCHB
# #SSO
# #SUBC
# #TGS
# #TOM
# #VEI
# #YAR
# #EDP
# #GALP
# #NOS
# #NVG
# #RENE
# #ACS
# #ACX
# #AENA
# #ANA
# #APPS
# #BBVA
# #BKT
# #CABK
# #CAF
# #CASH2
# #CLNX
# #DIA1
# #EBRO
# #ELE
# #ENC
# #ENG
# #FAE
# #FCC
# #FDR
# #FER
# #GAS
# #GEST
# #GRF
# #HOME
# #IBE
# #IDR
# #ITX
# #LOG
# #MAP
# #MEL
# #MRL
# #OHL
# #PSG
# #REP
# #SAB2
# #SCYR
# #TEF
# #TRE
# #UNI2
# #VIS
# #AAK
# #ADDT.B
# #ALIG
# #ALIVSDB
# #AOI
# #ARJOB
# #ASSA.B
# #ATCO.A
# #ATRLJ.B
# #ATT
# #AXFO
# #AZA
# #BETS.B
# #BILI.A
# #BILL
# #BMAX
# #BONAV.B
# #BOOZT
# #BRAV
# #BURE
# #CAST
# #CLA.B
# #COIC
# #DIOS
# #EKTA.B
# #ENQSE
# #ESSITY.B
# #EVO
# #FABG
# #FING.B
# #GETI.B
# #GRNG
# #HEXA.B
# #HM.B
# #HMS
# #HOFI
# #HOLM.B
# #HPOL.B
# #HUFV.A
# #HUSQ.B
# #IJ
# #INDT
# #INDU.A
# #INDU.C
# #INVE.A
# #INVE.B
# #INWI
# #JM
# #KINV.B
# #LATOB
# #LIAB
# #LIFCO.B
# #LUMI
# #LUND.B
# #MEKO
# #MTG.B
# #MTRS
# #MYCR
# #NCC.B
# #NOBI
# #NOLA.B
# #PEAB.B
# #PNDX.B
# #RATO.B
# #RAY.B
# #RESURS
# #SAAB.B
# #SCA.B
# #SEB.A
# #SECU.B
# #SHB.B
# #SHOT
# #SKA.B
# #SKF.B
# #STER
# #SWED.A
# #THULE
# #TREL.B
# #VITR
# #VOLV.A
# #WALL.B
# #WIHL
# #888
# #AAL
# #ABF
# #ADM
# #AHT
# #ANTO
# #AO.
# #ASCL
# #ASHM
# #AUTO
# #AV
# #AVST
# #AVV
# #BAB
# #BAE
# #BAG
# #BARC
# #BATS
# #BBOX
# #BDEV
# #BEZ
# #BGEO
# #BIFF
# #BKG
# #BLND
# #BLT
# #BNZL
# #BOY
# #BP
# #BRBY
# #BRW
# #BT
# #BVIC
# #BWY
# #BYG
# #CARD
# #CCH
# #CCL
# #CCPC
# #CEY
# #CHG
# #CINE
# #CKN
# #CMCX
# #CNA
# #CNE
# #COA
# #CPG
# #CPI
# #CRDA
# #CRST
# #CSN
# #CSP
# #CTEC
# #CTY
# #CWK
# #DCC
# #DGE
# #DLAR
# #DLG
# #DLN
# #DNLM
# #DPH
# #DPLM
# #DRX
# #DTY
# #DVO
# #ELM
# #EMG
# #ERM
# #ESP
# #EXPN
# #EZJ
# #FCSS
# #FDM
# #FEV
# #FGP
# #FORT
# #FRES
# #FSJ
# #FXPO
# #GAW
# #GENL
# #GFRD
# #GFTU
# #GLEN
# #GNS
# #GOG
# #GRG
# #GRI
# #GSK
# #HFD
# #HIK
# #HILS
# #HLMA
# #HMSO
# #HOC
# #HSBA
# #HSX
# #HTG
# #HVPE
# #HWDN
# #IAG
# #IBST
# #ICP
# #IGG
# #IHG
# #III
# #IMB
# #IMI
# #INCH
# #INDV
# #INF
# #INPP
# #INVP
# #IPF
# #IPO
# #ITRK
# #ITV
# #IWG
# #JD.
# #JDW
# #JMAT
# #JRP
# #KGF
# #KIE
# #KLR
# #LAND
# #LGEN
# #LLOY
# #LMP
# #LSE
# #MAB
# #MARS
# #MCRO
# #MDC
# #MGAM
# #MGGT
# #MGNS
# #MKS
# #MNDI
# #MNKS
# #MNZS
# #MONY
# #MSLH
# #MTO
# #MTRO
# #NCC
# #NG
# #NRR
# #NXT
# #OCDO
# #OSB
# #OTB
# #OXIG
# #PAGE
# #PCT
# #PCTN
# #PFC
# #PFD
# #PFG
# #PHNX
# #PHP
# #PLUS500
# #PNN
# #POLY
# #PRU
# #PSN
# #PSON
# #PTEC
# #PZC
# #QQ.
# #RAT
# #RBS
# #RCP
# #RDW
# #REL
# #RHIM
# #RIO
# #RMV
# #RNK
# #ROR
# #RR
# #RSW
# #RTO
# #S32
# #SAFE
# #SAGA
# #SBRY
# #SCT
# #SDR
# #SGC
# #SGE
# #SGRO
# #SHI
# #SKS
# #SMDS
# #SMIN
# #SMWH
# #SPI
# #SPT
# #SRP
# #SSE
# #SSPG
# #STAN
# #STJ
# #SVS
# #SVT
# #SXS
# #TATE
# #TBCG
# #TED
# #TEM
# #TIFS
# #TLPR
# #TLW
# #TPK
# #TRIG
# #TSCO
# #TTG
# #TW
# #ULE
# #ULVR
# #UTG
# #UU
# #VEIL
# #VOD
# #VSVS
# #WEIR
# #WG.
# #WIZZ
# #WKP
# #WPP
# #WTB
# #WWH
# #CQP
# #AWK
# #AZO
# #BAX
# #BBWI.US
# #BBY
# #BEN
# #BF.B
# #BIIB
# #BIO
# #BKR
# #BWA
# #BXP
# #CARR.US
# #CBG
# #CE
# #CF
# #CFG
# #CHD
# #CHKP
# #CHRW
# #CINF
# #CMA
# #CMG
# #CMS
# #CNC
# #CNP.US
# #CPB
# #CPRT
# #CRH
# #CRL.US
# #CTLT
# #CTVA
# #DAL
# #DDNY
# #DFS
# #DGX
# #DHI
# #DLR
# #DLTR
# #DOW
# #DPZ
# #DRE
# #FSP
# #GSAT
# #GTE
# #IMO
# #LNG
# #MAG
# #NAK
# #NGD
# #NHC
# #REI
# #SVM
# #TMP
# #RUN
# #RUSHA
# #RVNC
# #RY
# #RCKT.US
# #RPD.US
# #RVMD.US
# #SAFM
# #SAGE
# #SAIA
# #SANM
# #SASR
# #SAVE
# #SBAC
# #SBCF
# #SBGI
# #SBRA
# #SBSI
# #SBUX
# #SCCO
# #SCHL
# #SCI
# #SCSC
# #SCWX
# #SEDG
# #SEE
# #ARI
# #ARNC
# #AROC
# #ARR
# #ASB
# #ASGN
# #ASIX
# #ATEN
# #ATGE
# #ATI
# #ATKR
# #AVA
# #AVT
# #AWI
# #AWR
# #AXL
# #AYI
# #AZUL
# #AZZ
# #B
# #BANC
# #BBD
# #BCC
# #BCO
# #BDC
# #BDN
# #BEST
# #BFS
# #BHE
# #BHF
# #BHLB
# #BIG
# #BKD
# #BKE
# #BKH
# #BKU
# #BLX
# #BMA
# #BMI
# #BOH
# #BOX
# #BRC
# #BSM
# #BTU
# #BVN
# #BW
# #BXMT
# #BZH
# #CAPL
# #CARS
# #CATO
# #CBD
# #CBT
# #CBU
# #CBZ
# #CC
# #CCU
# #CDE
# #CEIX
# #CEQP
# #CHS
# #CIM
# #CIR
# #CLB
# #CLDT
# #CLH
# #CLS
# #CLW
# #CMC
# #CMP
# #CMRE
# #CNDT
# #CNK
# #CNO
# #CNS
# #COMM
# #CORR
# #CPA
# #CPE
# #CPF
# #CPK
# #CPS
# #CRI
# #CRS
# #CSTM
# #CTS
# #CUBI
# #CVEO
# #CW
# #CWH
# #CWT
# #CXW
# #CYH
# #DAN
# #DDS
# #DEA
# #DFIN
# #DIN
# #DK
# #DLNG
# #DLX
# #DNOW
# #DOC
# #DOOR
# #DRH
# #DRQ
# #DY
# #EAT
# #EFC
# #EGHT
# #EGO
# #EIG
# #ELF
# #ENLC
# #ENR
# #ENS
# #ENV
# #EPAC
# #EPC
# #EPR
# #EPRT
# #EQC
# #EQT
# #ERJ
# #ESE
# #ESRT
# #ETHNY
# #EVH
# #EVTC
# #EXP
# #EXPR
# #FBP
# #FCFS
# #FCN
# #FCPT
# #FDP
# #FET
# #FF
# #FIX
# #FLO
# #FLR
# #FN
# #FNB
# #FOR
# #FSM
# #FSS
# #FTAI
# #FTI
# #FTK
# #FUL
# #GATX
# #GBXNY
# #GCI
# #GDOT
# #GEF
# #GELNY
# #GEO
# #GES
# #GFF
# #GHL
# #GKOS
# #GLOP
# #GLP
# #GLT
# #GME
# #GMS
# #GNL
# #GNW
# #GOL
# #GOLF
# #GPI
# #GPK
# #GPMT
# #GRC
# #GSBD
# #GT
# #GTN
# #GTY
# #GVA
# #HASI
# #HBM
# #HE
# #HEP
# #HGV
# #HI
# #HL
# #HLI
# #HLX
# #HMN
# #HMY
# #HNI
# #HP
# #HPP
# #HR
# #HRB
# #HSC
# #HT
# #HTGC
# #HTH
# #HXL
# #IAG.US
# #IBP
# #IDA
# #IGT
# #IMAX
# #INN
# #INT
# #IRT
# #ITGR
# #IVR
# #JBGS
# #JBT
# #JELD
# #JKS
# #JOE
# #KAMN
# #KAR
# #KBH
# #KBR
# #KEX
# #KFY
# #KMPR
# #KMT
# #KOP
# #KOS
# #KRG
# #KTB
# #KW
# #LADR
# #LAZ
# #LC
# #LCI
# #LCII
# #LL
# #LNN
# #LPX
# #LRN
# #LTCNY
# #LXP
# #LZB
# #M
# #MAC
# #MAIN
# #MBI
# #MCY
# #MD
# #MED
# #MEI
# #MFA
# #MG
# #MHO
# #MIC
# #MITT
# #MLI
# #MMI
# #MOD
# #MOV
# #MSM
# #MTDR
# #MTG
# #MTH
# #MTOR
# #MTRN
# #MTW
# #MUR
# #MUSA
# #MUX
# #MWA
# #MXL
# #NAT
# #NBHC
# #NBR
# #NCR
# #NEWR
# #NGL
# #NGVT
# #NHI
# #NJR
# #NLS
# #NNI
# #NOAH
# #NOK
# #NOMD
# #NPO
# #NR
# #NS
# #NSA
# #NSP
# #NTB
# #NUS
# #NWE
# #NWN
# #NX
# #NYCB
# #OCN
# #OEC
# #OFC
# #OFG
# #OGS
# #OI.US
# #OII
# #OIS
# #OLN
# #OMI
# #ORC
# #OUT
# #OXM
# #PACW
# #PAGP
# #PBF
# #PBH
# #PBI
# #PDM
# #PDS
# #PEB
# #PFS
# #PFSI
# #PGRE
# #PGTI
# #PJT
# #PK
# #PLOW
# #PMT
# #PNM
# #POR
# #PRA
# #PRO
# #PRTY
# #PSB
# #PUMP
# #QD
# #QUAD
# #QUOT
# #R
# #RAD
# #RDN
# #RES
# #RGR
# #RGS
# #RHP
# #RIG
# #RLGY
# #RLI
# #RLJ
# #RMAX
# #RPT
# #RRC
# #RWT
# #RYAM
# #RYN
# #SA
# #SABR
# #SAH
# #SATS
# #SBH
# #SCL
# #SCS
# #SCU
# #SD
# #SEAS
# #SEM
# #SFBS
# #SFIX
# #SFM
# #SFNC
# #SGMO
# #SGMS
# #SGRY
# #SHEN
# #SHOO
# #SHW
# #SIGI
# #SIRI
# #SKYW
# #SLAB
# #SLG
# #SLGN
# #SLM
# #SLRC
# #SMPL
# #SMTC
# #SNBR
# #SNCR
# #SNEX
# #SOHU
# #SONO
# #SP
# #SPG
# #SPLK
# #SPPI
# #SPSC
# #SPTN
# #SPWR
# #SRCE
# #SRCL
# #SRPT
# #SSB
# #SSRM
# #SSYS
# #STBA
# #STKL
# #STRA
# #STWD
# #SUPN
# #STX
# #SWKS
# #SYF
# #SYNA
# #SYY
# #SAFT.US
# #SDGR.US
# #SILK.US
# #SNDX.US
# #SVC.US
# #TAST
# #TBBK
# #TBK
# #TBPH
# #TCBI
# #TCBK
# #TCPC
# #TDG
# #TECH
# #TELL
# #TFSL
# #TGTX
# #THRM
# #TILE
# #TLRY
# #TMO
# #TMUS
# #TREE
# #TRGP
# #TRIP
# #TRMB
# #TRMK
# #TROW
# #TRP
# #TRS
# #TRST
# #TSC
# #TSEM
# #TSLA
# #TSCO.US
# #TTD
# #TTEC
# #TTEK
# #TTMI
# #TU
# #TWNK
# #TWOU
# #TXRH
# #TXT
# #TYL
# #UAA
# #TRUP.US
# #TTGT.US
# #TVTX.US
# #TWST.US
# #UBSI
# #UCBI
# #UCTT
# #UEIC
# #UFCS
# #UFPI
# #UGI
# #UHS
# #UFPT
# #UMBF
# #UNFI
# #UNIT
# #URBN
# #URI
# #USFD
# #UVSP
# #UPST.US
# #UPWK.US
# #VBTX
# #VECO
# #VEON
# #VFC
# #VIAV
# #VIRT
# #VNDA
# #VNOM
# #VOYA
# #VREX
# #VRM
# #VRNS
# #VRNT
# #VRSK
# #VRSN
# #VRTX
# #VSAT
# #VCEL.US
# #VCYT.US
# #VRRM.US
# #VRTS.US
# #WABC
# #WAFD
# #WDFC
# #WEN
# #WERN
# #WING
# #WIRE
# #WIX
# #WDC
# #VTRS.US
# #WM
# #WRLD
# #WSBC
# #WSBF
# #WMG
# #WSC
# #WSFS
# #WTFC
# #WWD
# #WY
# #WW
# #XENT
# #XNCR
# #XPER
# #XPO
# #XPEL.US
# #YPF
# #ZBH
# #ZBRA
# #YY
# #ZLAB
# #AVGO
# #AXP
# #BAC
# #BDX
# #BIDU
# #BLK
# #BMO
# #BMRN
# #BMY
# #BNS
# #BOKF
# #BRKB
# #BPUS
# #BRO
# #BRX
# #BSX
# #BSAC
# #BTI
# #BUD
# #BURL
# #BWXT
# #BX
# #BYD
# #C
# #CACC
# #CACI
# #CAE
# #CAJ
# #CAT
# #CB
# #CBSH
# #CCI
# #CCJ
# #CCK
# #CCL.US
# #CGC
# #CHE
# #CHGG
# #CHH
# #CHT
# #CHTR
# #CI
# #CHWY
# #CIB
# #CIEN
# #CL
# #CLF
# #CM
# #CNHI
# #CNI
# #COPNY
# #COLD
# #COTY
# #CP
# #CPT
# #CRM
# #CSGP
# #CUBE
# #CUK
# #CUZ
# #CVE
# #CVNA
# #CVS
# #CVX
# #D
# #CX
# #DAR
# #DDD
# #DECK
# #DEI
# #DELL
# #DEO
# #DHR
# #DIS
# #DG.US
# #DKS
# #DLB
# #DOX
# #DUK
# #DRI
# #DVA
# #DVN
# #DXC
# #DXCM
# #DQ
# #DTE.US
# #E
# #EA
# #EBR
# #EBS
# #EC
# #ECL
# #ED
# #EDU
# #EFX
# #EGP
# #EIX
# #EL
# #EME
# #EMN
# #EMR
# #ENB
# #EOG
# #EPAM
# #EPD
# #EQIX
# #EQR
# #ES
# #ESS
# #ETN
# #ETR
# #EW
# #EVRG.US
# #EXC
# #EQNR.US
# #EXEL
# #EXPE
# #EXR
# #F
# #FANG
# #FCX
# #FDS
# #FE
# #FFIV
# #FHN
# #FICO
# #FIS
# #FITB
# #FIZZ
# #FL
# #FLS
# #FLT
# #FMS
# #FND
# #FRT
# #FSLR
# #FTNT
# #FTV
# #FTCH
# #FVRR
# #FWONK
# #G
# #GD
# #GDDY
# #GE
# #GFI
# #GIB
# #GLOB
# #GLUS
# #GLW
# #GM
# #GMED
# #GNRC
# #GNTX
# #GOOS
# #GPC
# #GPN
# #GPS
# #GRMN
# #GS
# #GWRE
# #GWW
# #H
# #HAE
# #HAL
# #HBAN
# #HBI
# #HCA
# #HD
# #HDB
# #HEICO
# #HES
# #HIG
# #HII
# #HLF
# #HLT
# #HMC
# #HNP
# #HOG
# #HOLX
# #HON
# #HPE
# #HPQ
# #HSBC
# #HSIC
# #HST
# #HSY
# #HTA
# #HUBB
# #HUBS
# #HUM
# #HUN
# #IBM
# #HUYA
# #IAA
# #IBN
# #ICE
# #HWM.US
# #IDXX
# #IEX
# #ILMN
# #IIPR.US
# #INFY
# #ING
# #INGR
# #IONS
# #IP
# #IPG
# #IPGP
# #IQV
# #IR
# #IT
# #ITT
# #ITUB
# #IX
# #JAZZ
# #J.US
# #JBHT
# #JBL
# #JCI
# #JHG
# #JKHY
# #JNJ
# #JNPR
# #JPM
# #JHX
# #KB
# #KEP
# #KEY
# #KEYS
# #KGC
# #KHC
# #KIM
# #KKR
# #KLAC
# #KMB
# #KMI
# #KMX
# #KNX
# #KO
# #KORS
# #KR
# #KSS
# #KT
# #KWR
# #L
# #LAD
# #LAMR
# #LBRDA
# #LEA
# #LECO
# #LEG.US
# #LEN
# #LH
# #LII
# #LHX
# #LKQ
# #LLY
# #LMT
# #LIN.US
# #LPL
# #LRCX
# #LSI
# #LSXMK
# #LULU
# #LUMN
# #LUV
# #LYB
# #LYV
# #MA
# #MAA
# #MAT
# #MCD
# #MAS.US
# #MCHP
# #MCK
# #MDT
# #MDU
# #MET
# #MFC
# #MGM
# #MKC
# #MKTX
# #MMC
# #MMM
# #MMP
# #MMS
# #MNST
# #MO
# #MOH
# #MOS
# #MPC
# #MPLX
# #MPW
# #MRK
# #MRO
# #MRVL
# #MS
# #MSA
# #MT
# #MTB
# #MTCH
# #MTD
# #MTN
# #MTZ
# #NDAQ
# #NDSN
# #NEM
# #NEP
# #NET
# #NGG
# #NI
# #NKE
# #NLSN
# #NIO.US
# #NLY
# #NMR
# #NNN
# #NOC
# #NOW
# #NRG
# #NSC
# #NTAP
# #NTRS
# #NUE
# #NVRO
# #NVR.US
# #NWL
# #NWS
# #NXPI
# #NYT
# #O
# #ODFL
# #OGE
# #OHI
# #OLED
# #OMC
# #OMF
# #ON
# #ORCL
# #ORI
# #OSK
# #OTEX
# #OTIS.US
# #OXY
# #OVV
# #PAA
# #PANW
# #PAYC
# #PB
# #PBA
# #PBR
# #PBRA
# #PCAR
# #PCG
# #PEAK
# #PEG
# #PEN
# #PFE
# #PFGC
# #PG
# #PGR
# #PH
# #PHG
# #PHI
# #PHM
# #PKG
# #PINS.US
# #PKX
# #PLD
# #PLNT
# #PM
# #PNC
# #PNR
# #PNW
# #PLTR
# #POST
# #PPG
# #PPL
# #PRGO
# #PRI
# #PRLB
# #PSA
# #PSO
# #PSTG
# #PSX
# #PUK
# #PVH
# #PWR
# #QGEN
# #QRVO
# #QS.US
# #QSR
# #QTWO
# #RACE
# #RBA
# #RBLX.US
# #RCI
# #RDY
# #RE
# #REG
# #PRU.US
# #REGN
# #REXR
# #RF
# #RGA
# #RGLD
# #RH
# #RHI
# #RJF
# #RL
# #RMD
# #RNG
# #RNR
# #ROL
# #ROP
# #ROST
# #RS
# #RSG
# #RYAAY
# #SAIC
# #SAIL
# #SAM
# #SBNY
# #SCHW
# #SBS.US
# #SE
# #SEIC
# #SF
# #SFL
# #SGEN
# #SHAK
# #SHG
# #SHO
# #SHOP
# #SIG
# #SITE
# #SITC
# #SIX
# #SJM
# #SJW
# #SKM
# #SKT
# #SKX
# #SLB
# #SLCA
# #SLF
# #SM
# #SMFG
# #SMG
# #SNA
# #SNAP
# #SNDR
# #SNE
# #SNN
# #SNOW
# #SNPS
# #SNV
# #SNX
# #SNY
# #SO
# #SPB
# #SPGI
# #SPH
# #SPXC
# #SON
# #SPOT.US
# #SQ
# #SQM
# #SR
# #SRC
# #SRG
# #SSD
# #SSL
# #SSNC
# #SSP
# #SSTK
# #ST
# #STAG
# #STAR
# #STC
# #SRE
# #STE
# #STLD
# #STM
# #STNG
# #STT
# #SUI
# #SUM
# #SUP
# #STZ
# #SWK
# #SWN
# #SXC
# #SXT
# #SYK
# #T
# #TAK
# #TAL
# #TARO
# #TBI
# #TD
# #TDC
# #TDOC
# #TDS
# #TDW
# #TCOM
# #TDY
# #TEAM
# #TECK
# #TEO
# #TEL
# #TER
# #TEVA
# #TEX
# #TFX
# #TG
# #TGH
# #TGI
# #TGNA
# #TFC
# #TGT
# #THC
# #THG
# #THO
# #THR
# #THS
# #TISI
# #TJX
# #TK
# #TKC
# #TKR
# #TLK
# #TM
# #TMHC
# #TMST
# #TNC
# #TME
# #TOL
# #TPC
# #TPH
# #TPR
# #TPX
# #TREX
# #TRN
# #TRNO
# #TROX
# #TRTN
# #TRU
# #TRV
# #TS
# #TSE
# #TSLX
# #TSM
# #TSN
# #TTC
# #TTE.US
# #TTM
# #TT.US
# #TTWO
# #TUP
# #TV
# #TWI
# #TWLO
# #TWO
# #TX
# #TXN
# #UA
# #UAL
# #UBA
# #U.US
# #UBER
# #UBS
# #UDR
# #UE
# #UFI
# #UGP
# #UHAL
# #UHT
# #UIS
# #ULTA
# #UINY
# #UL.US
# #UMC
# #UNH
# #UNM
# #UNP
# #UNVR
# #UPS
# #USAC
# #USB
# #USM
# #USNA
# #USPH
# #UTHR
# #UTL
# #UVE
# #UVV
# #V
# #VALE
# #VC
# #VEEV
# #VG
# #VGR
# #VIPS
# #VIV
# #VLO
# #VLY
# #VMC
# #VMI
# #VMW
# #VNO
# #VRTV
# #VSH
# #VST
# #VSTO
# #VSCO.US
# #VTR
# #VVI
# #VVV
# #VZ
# #W
# #WAB
# #WAL
# #WAT
# #WB
# #WBA
# #WBS
# #WBT
# #WCC
# #WCN
# #WD
# #WDAY
# #WEC
# #WEX
# #WFC
# #WGO
# #WELL
# #WHR
# #WIT
# #WLK
# #WHG
# #WLTW
# #WMB
# #WMC
# #WMK
# #WMS
# #WMT
# #WNC
# #WPC
# #WPM
# #WRB
# #WRE
# #WRK
# #WSM
# #WSO
# #WST
# #WTR
# #WTS
# #WU
# #WWE
# #WWW
# #WYNN
# #X
# #XEL
# #XHR
# #XOM
# #XRAY
# #XRX
# #XYL
# #XPEV
# #YELP
# #YUM
# #YUMC
# #Z
# #ZION
# #ZTS
# #ZSUS
# #A2M.AU
# #ABC.AU
# #AGL.AU
# #AKE.AU
# #ALG.AU
# #ALL.AU
# #ALQ.AU
# #ALU.AU
# #ALX.AU
# #AMC.AU
# #AMP.AU
# #ANN.AU
# #ANZ.AU
# #APA.AU
# #APX.AU
# #ARB.AU
# #ASX.AU
# #AWC.AU
# #AZJ.AU
# #BAP.AU
# #BEN.AU
# #BGA.AU
# #BHP.AU
# #BKL.AU
# #BKW.AU
# #BOQ.AU
# #BPT.AU
# #BRG.AU
# #BSL.AU
# #BVS.AU
# #BXB.AU
# #CAR.AU
# #CBA.AU
# #CCP.AU
# #CGC.AU
# #CGF.AU
# #CNU.AU
# #COH.AU
# #COL.AU
# #CPU.AU
# #CSL.AU
# #CSR.AU
# #CTD.AU
# #DMP.AU
# #DOW.AU
# #DXS.AU
# #ECX.AU
# #ELD.AU
# #EVN.AU
# #FBU.AU
# #FLT.AU
# #FMG.AU
# #FPH.AU
# #GMG.AU
# #GNC.AU
# #GPT.AU
# #GUD.AU
# #HLS.AU
# #HVN.AU
# #IAG.AU
# #IEL.AU
# #IFL.AU
# #IGO.AU
# #ILU.AU
# #ING.AU
# #IPH.AU
# #IPL.AU
# #IRE.AU
# #IVC.AU
# #JBH.AU
# #LLC.AU
# #LNK.AU
# #LYC.AU
# #MFG.AU
# #MIN.AU
# #MMS.AU
# #MND.AU
# #MPL.AU
# #MQG.AU
# #MTS.AU
# #NAB.AU
# #NAN.AU
# #NCM.AU
# #NHC.AU
# #NHF.AU
# #NST.AU
# #NUF.AU
# #NWS.AU
# #NXT.AU
# #ORG.AU
# #ORI.AU
# #OZL.AU
# #PGH.AU
# #PMV.AU
# #PPT.AU
# #PTM.AU
# #QAN.AU
# #QBE.AU
# #REA.AU
# #RHC.AU
# #RIO.AU
# #RMD.AU
# #RRL.AU
# #RSG.AU
# #RWC.AU
# #S32.AU
# #SBM.AU
# #SCG.AU
# #SDF.AU
# #SEK.AU
# #SFR.AU
# #SGM.AU
# #SGP.AU
# #SGR.AU
# #SHL.AU
# #SIQ.AU
# #SKC.AU
# #SOL.AU
# #SPK.AU
# #STO.AU
# #SUL.AU
# #SUN.AU
# #SVW.AU
# #TCL.AU
# #TLS.AU
# #TNE.AU
# #TWE.AU
# #VCX.AU
# #WBC.AU
# #WEB.AU
# #WES.AU
# #WHC.AU
# #WOR.AU
# #WOW.AU
# #WPL.AU
# #WTC.AU
# #XRO.AU
# #1332.JP
# #1605.JP
# #1721.JP
# #1801.JP
# #1802.JP
# #1803.JP
# #1808.JP
# #1812.JP
# #1925.JP
# #1928.JP
# #1963.JP
# #2002.JP
# #2269.JP
# #2282.JP
# #2432.JP
# #2501.JP
# #2502.JP
# #2503.JP
# #2531.JP
# #2801.JP
# #2802.JP
# #2871.JP
# #2914.JP
# #3086.JP
# #3099.JP
# #3101.JP
# #3105.JP
# #3382.JP
# #3401.JP
# #3405.JP
# #3407.JP
# #3436.JP
# #3865.JP
# #4004.JP
# #4021.JP
# #4042.JP
# #4043.JP
# #4061.JP
# #4063.JP
# #4151.JP
# #4183.JP
# #4208.JP
# #4272.JP
# #4324.JP
# #4452.JP
# #4502.JP
# #4503.JP
# #4506.JP
# #4507.JP
# #4519.JP
# #4523.JP
# #4543.JP
# #4568.JP
# #4704.JP
# #4755.JP
# #4901.JP
# #4902.JP
# #4911.JP
# #5101.JP
# #5108.JP
# #5201.JP
# #5202.JP
# #5214.JP
# #5232.JP
# #5233.JP
# #5301.JP
# #5332.JP
# #5333.JP
# #5401.JP
# #5406.JP
# #5411.JP
# #5541.JP
# #5631.JP
# #5706.JP
# #5707.JP
# #5711.JP
# #5713.JP
# #5714.JP
# #5801.JP
# #5901.JP
# #6103.JP
# #6113.JP
# #6301.JP
# #6302.JP
# #6305.JP
# #6326.JP
# #6361.JP
# #6367.JP
# #6471.JP
# #6473.JP
# #6479.JP
# #6501.JP
# #6502.JP
# #6503.JP
# #6504.JP
# #6506.JP
# #6508.JP
# #6674.JP
# #6701.JP
# #6702.JP
# #6703.JP
# #6752.JP
# #6758.JP
# #6762.JP
# #6770.JP
# #6841.JP
# #6857.JP
# #6861.JP
# #6902.JP
# #6952.JP
# #6954.JP
# #6971.JP
# #6976.JP
# #6988.JP
# #7003.JP
# #7011.JP
# #7012.JP
# #7013.JP
# #7201.JP
# #7202.JP
# #7203.JP
# #7205.JP
# #7261.JP
# #7267.JP
# #7269.JP
# #7270.JP
# #7272.JP
# #7731.JP
# #7733.JP
# #7735.JP
# #7751.JP
# #7752.JP
# #7762.JP
# #7911.JP
# #7912.JP
# #7951.JP
# #7974.JP
# #8001.JP
# #8015.JP
# #8031.JP
# #8035.JP
# #8053.JP
# #8058.JP
# #8185.JP
# #8233.JP
# #8252.JP
# #8253.JP
# #8267.JP
# #8304.JP
# #8316.JP
# #8331.JP
# #8354.JP
# #8591.JP
# #8628.JP
# #8630.JP
# #8725.JP
# #8766.JP
# #8795.JP
# #8801.JP
# #8802.JP
# #8804.JP
# #8830.JP
# #9001.JP
# #9005.JP
# #9007.JP
# #9008.JP
# #9009.JP
# #9020.JP
# #9021.JP
# #9022.JP
# #9064.JP
# #9101.JP
# #9104.JP
# #9107.JP
# #9202.JP
# #9301.JP
# #9432.JP
# #9433.JP
# #9501.JP
# #9502.JP
# #9503.JP
# #9531.JP
# #9532.JP
# #9602.JP
# #9613.JP
# #9735.JP
# #9766.JP
# #9983.JP
# #9984.JP
# #YRD
# #ZNH
# #ZTO
# #SANES
# #SU
# #UBI
# #URW
# #WLD
# #EXXT
# #RBOT
# #China50_J3
# #USDX_M3
# _AUS200_M3
# _Canada60_M3
# _DUTCH25_J3
# _ES_M3
# AUDDKK
# AUDHUF
# AUDNOK
# AUDPLN
# AUDSEK
# AUDSGD
# CADMXN
# CHFDKK
# CHFHUF
# CHFNOK
# CHFPLN
# CHFSEK
# CHFSGD
# EURDKK
# EURHKD
# EURMXN
# EURSGD
# EURZAR
# GBPCZK
# GBPDKK
# GBPHUF
# GBPMXN
# GBPNOK
# GBPSEK
# GBPZAR
# HKDJPY
# NOKSEK
# SGDJPY
# USDDKK
# USDTHB
# USDTRY
# #ZOOM
# #XSOE
# _EURO50_M3
# _GER40_M3
# _GermanyTech30_M3
# _HK50_J3
# _HSCEI50_J3
# _MidCapGER50_M3
# _ARABICA_K3
# _ARABICA_N3
# _COCOA_K3
# _COPPER_K3
# #CTRA.US
# #ZD.US
# #RRX.US
# #ZWS.US
# #SLVM.US
# #XPRO.US
# #WOLF.US
# #ET.US
# #AZTA.US
# #SHEL.UK
# #SHEL.US
# #PARA.US
# #CEG.US
# _NORWAY25_J3
# _SPAIN35_J3
# _STXE600_M3
# _SWISS20_M3
# _Singapore25_H3
# _Singapore25_J3
# _SouthAfrica40_M3
# _UK100_M3
# _COTTON_K3
# #WBD.US
# #ZNTL.US
# #FRHC.US
# #DINO.US
# #VICI.US
# #BALL.US
# _USNASDAQ100_M3
# #RED.ES
# _COTTON_N3
# _CrudeOilUK_K3
# _CrudeOilUK_M3
# _CrudeOilUK_N3
# _CrudeOilUS_K3
# _CrudeOilUS_M3
# _ORANGE.JUICE_K3
# _ROBUSTA_K3
# _SUGAR.RAW_K3
# #ELV.US
# _SUGAR.WHITE_K3
# #APE.US
# #Bund_H3
# #Bund_M3
# #Bund_U3
# #USTNote_H3
# _Volatility_J3
# _YM_M3
# #COHR.US
# #PR.US
# #ADEA.US
# #GEN.US
# #AFRM.US
# #ALGM.US
# #ALHC.US
# #ALTR.US
# #APLS.US
# #APP.US
# #ARRY.US
# #ARWR.US
# #ASND.US
# #ASO.US
# #AUB.US
# #BANF.US
# #BCRX.US
# #BEAM.US
# #BLKB.US
# #BMBL.US
# #CCEP.US
# #CELH.US
# #CFLT.US
# #CHX.US
# #CLBK.US
# #CNXC.US
# #COKE.US
# #COOP.US
# #CRSP.US
# #DNLI.US
# #DNUT.US
# #DUOL.US
# #EBC.US
# #ERIE.US
# #ESGR.US
# #ESLT.US
# #FOCS.US
# #FROG.US
# #FRPT.US
# #FRSH.US
# #FUTU.US
# #GDRX.US
# #GLBE.US
# #GLPG.US
# #GO.US
# #GRFS.US
# #GTLB.US
# #HLNE.US
# #HTZ.US
# #HWC.US
# #IAC.US
# #INDB.US
# #JAMF.US
# #KNBE.US
# #LAZR.US
# #MDB.US
# #MEDP.US
# #MIDD.US
# #MNDY.US
# #MORN.US
# #MQ.US
# #MRTX.US
# #NARI.US
# #NCNO.US
# #NFE.US
# #NOVT.US
# #NTRA.US
# #NVEE.US
# #OPCH.US
# #OZK.US
# #PGNY.US
# #QDEL.US
# #RCM.US
# #RIVN.US
# #ROKU.US
# #RPRX.US
# #SIMO.US
# #SMCI.US
# #SOFI.US
# #SPT.US
# #STAA.US
# #STNE.US
# #SWAV.US
# #SYBT.US
# #SYNH.US
# #TENB.US
# #TNDM.US
# #TOWN.US
# #TWKS.US
# #TXG.US
# #VICR.US
# #VIR.US
# #VOD.US
# #WFRD.US
# #WOOF.US
# #XP.US
# #ZG.US
# #ZI.US
# #AI.US
# #AIR.US
# #AVNS.US
# #BFH.US
# #BGS.US
# #BHVN.US
# #BOOT.US
# #BROS.US
# #CCS.US
# #CNNE.US
# #COUR.US
# #DAC.US
# #DHT.US
# #EAF.US
# #ECVT.US
# #ENVA.US
# #EVRI.US
# #FBK.US
# #FBRT.US
# #FCF.US
# #FORG.US
# #FSLY.US
# #HAYW.US
# #HCC.US
# #HLIO.US
# #KD.US
# #KN.US
# #KREF.US
# #KRO.US
# #LMND.US
# #MEG.US
# #MODN.US
# #MTX.US
# #NABL.US
# #NG.US
# #NXE.US
# #NXRT.US
# #PAY.US
# #PD.US
# #RAMP.US
# #RC.US
# #RCUS.US
# #ROG.US
# #RVLV.US
# #SWI.US
# #SXI.US
# #TALO.US
# #TNK.US
# #UEC.US
# #UUUU.US
# #VRE.US
# #WTI.US
# #WTTR.US
# #ABG.US
# #ACA.US
# #ACI.US
# #AGL.US
# #AGR.US
# #AIRC.US
# #ALV.US
# #AMG.US
# #AMRC.US
# #ARES.US
# #ARW.US
# #ASAI.US
# #ATCO.US
# #AVNT.US
# #AVTR.US
# #BBVA.US
# #BEKE.US
# #BILL.US
# #BSBR.US
# #CADE.US
# #CALX.US
# #CFR.US
# #CHPT.US
# #CIVI.US
# #CLVT.US
# #CNA.US
# #CPNG.US
# #CRK.US
# #CVI.US
# #CWEN.US
# #CWK.US
# #DASH.US
# #DAVA.US
# #DBRG.US
# #DOCN.US
# #DT.US
# #DTM.US
# #EDR.US
# #EHC.US
# #ELAN.US
# #EQH.US
# #ESI.US
# #ESNT.US
# #ESTC.US
# #ETRN.US
# #EVR.US
# #FHI.US
# #FR.US
# #FRO.US
# #GHC.US
# #GSK.US
# #GTES.US
# #GXO.US
# #HRI.US
# #ICL.US
# #IHG.US
# #INFA.US
# #INSP.US
# #JEF.US
# #JXN.US
# #KAI.US
# #KOF.US
# #LBRT.US
# #LEVI.US
# #LTHM.US
# #MAN.US
# #MANU.US
# #MATX.US
# #MC.US
# #MDC.US
# #MGY.US
# #MKL.US
# #MNSO.US
# #MP.US
# #MSGS.US
# #MUFG.US
# #MYOV.US
# #NEX.US
# #NOVA.US
# #NU.US
# #NVST.US
# #NVT.US
# #NWG.US
# #ONTO.US
# #ORA.US
# #OSH.US
# #PAC.US
# #PAG.US
# #PAGS.US
# #PAM.US
# #PATH.US
# #PSN.US
# #REZI.US
# #RIO.US
# #S.US
# #SAN.US
# #SAP.US
# #SBSW.US
# #SID.US
# #SKY.US
# #SMAR.US
# #SPR.US
# #STVN.US
# #SUZ.US
# #SWX.US
# #TEF.US
# #TIMB.US
# #TNET.US
# #TNL.US
# #TPL.US
# #TR.US
# #UNF.US
# #VAC.US
# #VNT.US
# #VRT.US
# #WH.US
# #WHD.US
# #WK.US
# #WNS.US
# #WOR.US
# #WTM.US
# #YETI.US
# #ZIM.US
# #FG.US
# #VTLE.US
# #USTNote_M3
# #SHC.UK
# #UPBD.US
# _XAU_M3
# #LSAK
# #CXT
# _DUTCH25_K3
# _FRANCE40_K3
# _NORWAY25_K3
# _SPAIN35_K3
# _Volatility_K3
# #China50_K3
# _Singapore25_K3
# _HK50_K3
# _HSCEI50_K3
# USDZAR
# _COPPER_N3
# _ORANGE.JUICE_N3
# _ROBUSTA_N3
# _SUGAR.RAW_N3
# _SUGAR.WHITE_Q3
# #SPHR.US
# _COCOA_N3
# _CrudeOilUS_N3
# _DUTCH25_M3
# _FRANCE40_M3
# _NORWAY25_M3
# _SPAIN35_M3
# _CrudeOilUK_Q3
# _Volatility_M3
# _XAU_Q3
# #RVTY.US
# #China50_M3
# _Singapore25_M3
# _HK50_M3
# _HSCEI50_M3
# #USTNote_U3
# _CrudeOilUS_Q3
# _COTTON_V3
# _ARABICA_U3
# _COCOA_U3
# _SWISS20_U3
# _AUS200_U3
# _Canada60_U3
# _STXE600_U3
# _SouthAfrica40_U3
# #USDX_U3
# _DUTCH25_N3
# _FRANCE40_N3
# _NORWAY25_N3
# _SPAIN35_N3
# _EURO50_U3
# _GER40_U3
# _GermanyTech30_U3
# _MidCapGER50_U3
# _UK100_U3
# _USNASDAQ100_U3
# _YM_U3
# _ES_U3
# _Volatility_N3
# _COPPER_U3
# #FRVIA.FR
# #FI.US
# _CrudeOilUK_U3
# _ROBUSTA_U3
# _ORANGE.JUICE_U3
# _SUGAR.RAW_V3
# #China50_N3
# _DUTCH25_Q3
# _HSCEI50_N3
# _Singapore25_N3
# _HK50_N3
# #CLARI.FR
# _CrudeOilUS_U3
# _SUGAR.WHITE_V3
# #BGC.US
# #DHL.DE
# _FRANCE40_Q3
# _NORWAY25_Q3
# _SPAIN35_Q3

# %%
symbols = mt5.symbols_get()

for symbol in symbols:
    if symbol.name == "EURUSD":
        print("exists")
# Out:
# exists

# %%
import time
from datetime import datetime

price = mt5.symbol_info_tick("EURUSD")
print(price)
# Out:
# Tick(time=1688774337, bid=1.09682, ask=1.09699, last=0.0, volume=0, time_msc=1688774337138, flags=6, volume_real=0.0)
